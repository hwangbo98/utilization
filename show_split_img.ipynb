# %%
from PIL import Image
import os
import matplotlib.pyplot as plt


# 이미지 경로를 저장할 리스트
# image_paths = ['/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208172034281000710497.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202204251916511000118672.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208172034311000710498.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208050724091000666281.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208050146351000664529.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208050724201000666285.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202209132246411000880120.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208172242091000711154.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208042152461000663298.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208041102271000659772.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208050724171000666284.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202204250630341000111990.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208172034101000710491.jpg',
# '/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202204210038161000059759.jpg',
# '/home/hwangbo/showniq_2nd_data/images/items/swimwear/beach_tops/beach_tops001/202208040446331000657891.jpg',
# '/home/hwangbo/showniq_2nd_data/images/items/swimwear/beach_tops/beach_tops001/202208040920461000659210.jpg',
# '/home/hwangbo/showniq_2nd_data/images/items/swimwear/beach_tops/beach_tops001/202208040446381000657893.jpg',
# '/home/hwangbo/showniq_2nd_data/images/items/swimwear/beach_tops/beach_tops001/202208040446511000657898.jpg',
# '/home/hwangbo/showniq_2nd_data/images/items/swimwear/beach_tops/beach_tops001/202208040446541000657899.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208031836181000655103.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208032150351000656014.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208032304131000656356.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208032150161000656006.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040802211000658751.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040920541000659213.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040710171000658520.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202210120050201000943879.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040920511000659212.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040710191000658521.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202211080010141001009298.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040710051000658516.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202211040648151000987737.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202211080112161001009602.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040250171000657369.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202210120050341000943883.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208041818381000662194.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208032150211000656008.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202211220218051001052741.jpg',
# '/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208031836201000655104.jpg'
# ]

image_paths = ['/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208032150141000656005.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202207271442041000606511.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208050146351000664529.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202209132246411000880120.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202209132246351000880118.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202206271946091000343355.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208172034221000710495.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202204250630341000111990.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208172034101000710491.jpg',
'/home/hwangbo/showniq_1st_data/images/items/swimwear/beach_tops/beach_tops001/202208050002091000663946.jpg',
'/home/hwangbo/showniq_2nd_data/images/items/swimwear/beach_tops/beach_tops001/202208040446491000657897.jpg',
'/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208032150251000656010.jpg',
'/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040022071000656683.jpg',
'/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040920511000659212.jpg',
'/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202210311102321000965940.jpg',
'/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208040710191000658521.jpg',
'/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202208032150371000656015.jpg',
'/home/hwangbo/showniq_4th_data/images/items/swimwear/beach_tops/beach_tops001/202207040700051000418411.jpg']
# 이미지 경로 추가하기
# image_paths.append("image1.png")
# image_paths.append("image2.png")
# image_paths.append("image3.png")

# 이미지를 분할하여 보여줄 새 이미지 생성
img_size = 900  # 이미지 크기
columns = 10  # 열 개수
rows = (len(image_paths) + columns - 1) // columns  # 행 개수
new_image = Image.new('RGB', (img_size * columns, img_size * rows))

# 이미지 분할하여 새 이미지에 병합하기
x_offset, y_offset = 0, 0
for path in image_paths:
    img = Image.open(path)
    img = img.resize((img_size, img_size))
    new_image.paste(img, (x_offset, y_offset))
    x_offset += img_size
    if x_offset == img_size * columns:
        x_offset = 0
        y_offset += img_size

# 새 이미지 보여주기
plt.imshow(new_image)
